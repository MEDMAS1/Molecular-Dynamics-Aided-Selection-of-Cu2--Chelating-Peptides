# %%
import parmed as pmd
#amber = pmd.load_file('prmtop', 'inpcrd'), dibawah ini adalah perintah untuk meload file dengan format amber
amber = pmd.load_file('Ca_cpx3.prmtop', 'Ca_cpx3.inpcrd')
#save a GROMACS topology and GRO file, dibawah ini adalah perintah untuk menyimpan file dalam format gromacs
amber.save('gromacs.top')
amber.save('gromacs.gro')

# %%
ls
# Out:
# 126_parmed.in                 frcmod.ions234lm_iod_tip3p
# cpx1_fixed_nonprot.pdb        gromacs.gro
# cpx1_fixed.pdb                gromacs.top
# cpx1_fixed_renum.txt          Hg_cpx3.inpcrd
# cpx1_fixed_sslink             Hg_cpx3.pdb
# cpx1.pdb                      Hg_cpx3.prmtop
# DM/                           Hg_tleap.in
# frcmod.ions234lm_126_tip3p    Hg_tleap.out
# frcmod.ions234lm_hfe_tip3p    leap.log
# frcmod.ions234lm_hfe_tip4pew  Parmed_AmbertoGromacs.ipynb

# %%
conda install -c conda-forge parmed -y
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install -c conda-forge parmed -y')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %%
pip install parmed
# Out:
# ...
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
# ...
